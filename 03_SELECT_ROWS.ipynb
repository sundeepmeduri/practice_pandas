# %%
import pandas as pd

# %%
df = pd.read_csv('FILES\sales_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sales_ID          100 non-null    int64
#  1   Date              100 non-null    object
#  2   Product           100 non-null    object
#  3   Revenue           100 non-null    int64
#  4   Quantity          100 non-null    int64
#  5   Profit            100 non-null    int64
#  6   Region            100 non-null    object
#  7   Customer_Type     100 non-null    object
#  8   Sales_Channel     100 non-null    object
#  9   Payment_Method    100 non-null    object
#  10  Shipping_Method   100 non-null    object
#  11  Promotion         100 non-null    object
#  12  Rating            100 non-null    int64
#  13  Customer_ID       100 non-null    int64
#  14  Customer_Name     100 non-null    object
#  15  Customer_Email    100 non-null    object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.shape
# Out:
# (100, 20)

# %%
df.loc[2]
# Out:
# Sales_ID                                1002
# Date                              2023-01-03
# Product                                    A
# Revenue                                  301
# Quantity                                   9
# Profit                                    66
# Region                                 South
# Customer_Type                      Returning
# Sales_Channel                         Online
# Payment_Method                        PayPal
# Shipping_Method                      Express
# Promotion                                 No
# Rating                                     5
# Customer_ID                             1002
# Customer_Name                  Customer 1002
# Customer_Email      customer1002@example.com
# Product_ID                                 7
# Product_Category                    Clothing
# Product_Price                            150
# Product_Discount                          24
# Name: 2, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#    Sales_ID        Date Product  Revenue  Quantity  Profit Region  \
# 0      1000  2023-01-01       A      654         8      61   West
# 1      1001  2023-01-02       B      468         9      18   West
# 2      1002  2023-01-03       A      301         9      66  South
#
#   Customer_Type Sales_Channel Payment_Method Shipping_Method Promotion  \
# 0           New        Online           Cash        Standard       Yes
# 1     Returning       Offline         PayPal         Express        No
# 2     Returning        Online         PayPal         Express        No
#
#    Rating  Customer_ID  Customer_Name            Customer_Email  Product_ID  \
# 0       4         1000  Customer 1000  customer1000@example.com          96
# 1       1         1001  Customer 1001  customer1001@example.com          46
# 2       5         1002  Customer 1002  customer1002@example.com           7
#
#   Product_Category  Product_Price  Product_Discount
# 0         Clothing            495                49
# ...

# %%
df = df.set_index('Sales_ID')

# %%
df.loc[[1000, 1001]]
# Out:
#                 Date Product  Revenue  Quantity  Profit Region Customer_Type  \
# Sales_ID
# 1000      2023-01-01       A      654         8      61   West           New
# 1001      2023-01-02       B      468         9      18   West     Returning
#
#          Sales_Channel Payment_Method Shipping_Method Promotion  Rating  \
# Sales_ID
# 1000            Online           Cash        Standard       Yes       4
# 1001           Offline         PayPal         Express        No       1
#
#           Customer_ID  Customer_Name            Customer_Email  Product_ID  \
# Sales_ID
# 1000             1000  Customer 1000  customer1000@example.com          96
# 1001             1001  Customer 1001  customer1001@example.com          46
#
#          Product_Category  Product_Price  Product_Discount
# Sales_ID
# 1000             Clothing            495                49
# 1001          Electronics            396                29

# %%
df.loc[1000:1005]
# Out:
#                 Date Product  Revenue  Quantity  Profit Region Customer_Type  \
# Sales_ID
# 1000      2023-01-01       A      654         8      61   West           New
# 1001      2023-01-02       B      468         9      18   West     Returning
# 1002      2023-01-03       A      301         9      66  South     Returning
# 1003      2023-01-04       B      483         3      97  South     Returning
# 1004      2023-01-05       B      612         9      42   West           New
# 1005      2023-01-06       C      470         7      29  South     Returning
#
#          Sales_Channel Payment_Method Shipping_Method Promotion  Rating  \
# Sales_ID
# 1000            Online           Cash        Standard       Yes       4
# 1001           Offline         PayPal         Express        No       1
# 1002            Online         PayPal         Express        No       5
# 1003           Offline         PayPal        Standard        No       4
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#     Sales_ID        Date Product  Revenue  Quantity  Profit Region  \
# 0       1000  2023-01-01       A      654         8      61   West
# 1       1001  2023-01-02       B      468         9      18   West
# 2       1002  2023-01-03       A      301         9      66  South
# 3       1003  2023-01-04       B      483         3      97  South
# 4       1004  2023-01-05       B      612         9      42   West
# ..       ...         ...     ...      ...       ...     ...    ...
# 95      1095  2023-04-06       A      221         1      40  South
# 96      1096  2023-04-07       C      426         5      64   West
# 97      1097  2023-04-08       A      569         9      35  North
# 98      1098  2023-04-09       B      387         5      30   West
# 99      1099  2023-04-10       C      625         4      67   East
#
#    Customer_Type Sales_Channel Payment_Method Shipping_Method Promotion  \
# 0            New        Online           Cash        Standard       Yes
# ...

# %%
df.loc[0:5]
# Out:
#    Sales_ID        Date Product  Revenue  Quantity  Profit Region  \
# 0      1000  2023-01-01       A      654         8      61   West
# 1      1001  2023-01-02       B      468         9      18   West
# 2      1002  2023-01-03       A      301         9      66  South
# 3      1003  2023-01-04       B      483         3      97  South
# 4      1004  2023-01-05       B      612         9      42   West
# 5      1005  2023-01-06       C      470         7      29  South
#
#   Customer_Type Sales_Channel Payment_Method Shipping_Method Promotion  \
# 0           New        Online           Cash        Standard       Yes
# 1     Returning       Offline         PayPal         Express        No
# 2     Returning        Online         PayPal         Express        No
# 3     Returning       Offline         PayPal        Standard        No
# 4           New       Offline           Cash        Standard        No
# 5     Returning        Online           Cash        Standard        No
#
# ...

# %% [markdown]
# # using iloc

# %%
df.iloc[0]
# Out:
# Sales_ID                                1000
# Date                              2023-01-01
# Product                                    A
# Revenue                                  654
# Quantity                                   8
# Profit                                    61
# Region                                  West
# Customer_Type                            New
# Sales_Channel                         Online
# Payment_Method                          Cash
# Shipping_Method                     Standard
# Promotion                                Yes
# Rating                                     4
# Customer_ID                             1000
# Customer_Name                  Customer 1000
# Customer_Email      customer1000@example.com
# Product_ID                                96
# Product_Category                    Clothing
# Product_Price                            495
# Product_Discount                          49
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    Sales_ID        Date Product  Revenue  Quantity  Profit Region  \
# 0      1000  2023-01-01       A      654         8      61   West
# 1      1001  2023-01-02       B      468         9      18   West
# 2      1002  2023-01-03       A      301         9      66  South
# 3      1003  2023-01-04       B      483         3      97  South
# 4      1004  2023-01-05       B      612         9      42   West
#
#   Customer_Type Sales_Channel Payment_Method Shipping_Method Promotion  \
# 0           New        Online           Cash        Standard       Yes
# 1     Returning       Offline         PayPal         Express        No
# 2     Returning        Online         PayPal         Express        No
# 3     Returning       Offline         PayPal        Standard        No
# 4           New       Offline           Cash        Standard        No
#
#    Rating  Customer_ID  Customer_Name            Customer_Email  Product_ID  \
# ...

# %%
df.iloc[1000:1005] # nothing returns
# Out:
# Empty DataFrame
# Columns: [Date, Product, Revenue, Quantity, Profit, Region, Customer_Type, Sales_Channel, Payment_Method, Shipping_Method, Promotion, Rating, Customer_ID, Customer_Name, Customer_Email, Product_ID, Product_Category, Product_Price, Product_Discount]
# Index: []

# %%
df.iloc[[1,2,4,6]]
# Out:
#                 Date Product  Revenue  Quantity  Profit Region Customer_Type  \
# Sales_ID
# 1001      2023-01-02       B      468         9      18   West     Returning
# 1002      2023-01-03       A      301         9      66  South     Returning
# 1004      2023-01-05       B      612         9      42   West           New
# 1006      2023-01-07       A      655         7      82   West     Returning
#
#          Sales_Channel Payment_Method Shipping_Method Promotion  Rating  \
# Sales_ID
# 1001           Offline         PayPal         Express        No       1
# 1002            Online         PayPal         Express        No       5
# 1004           Offline           Cash        Standard        No       4
# 1006            Online           Cash        Standard        No       1
#
#           Customer_ID  Customer_Name            Customer_Email  Product_ID  \
# Sales_ID
# 1001             1001  Customer 1001  customer1001@example.com          46
# ...
